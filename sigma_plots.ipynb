# %%
import os
import json
import numpy as np
import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots
import re

estimator_colors = px.colors.qualitative.Dark24
color_pad = px.colors.qualitative.Dark24

# %%
ticks = 25
no_mus = 256
plot_x_data = [str(i) for i in np.arange(0, 100050, 50)]

def load_data(model_dir, model_key):
    mu_data = json.load(open(os.path.join(model_dir, "plot_data.json"), "r"))

    data = []
    final_epoch = 0
    for epoch in mu_data:
        if int(epoch) % 50 == 0:
            final_epoch = epoch
            data.append(mu_data[epoch][model_key])

    if epoch != plot_x_data[-1]:
        for _ in plot_x_data[plot_x_data.index(final_epoch)+1:]:
            data.append(data[-1])
    
    tick_size = int(len(plot_x_data) / ticks)

    plot_x_axis = []
    plot_y_axis = []
    
    index = 0

    while index <= len(plot_x_data):
        plot_x_axis.append(plot_x_data[index])
        plot_y_axis.append(data[index])
        index += tick_size

    return plot_x_axis, plot_y_axis

no_mus = 2
plot_x_axis, tf_small = load_data(f"good_sweep_1_fixed_256/sigma=1-mu={no_mus}-default_sigma=1-family=bert-hid_dim=4-mlp=0-layer=1-head=1-tokenizer=learnable", "d_m_t")
plot_x_axis, tf_med = load_data(f"good_sweep_1_fixed_256/sigma=1-mu={no_mus}-default_sigma=1-family=bert-hid_dim=16-mlp=0-layer=1-head=2-tokenizer=learnable", "d_m_t")
# plot_x_axis, tf_large = load_data(f"good_sweep_1_fixed_256/sigma=1-mu={no_mus}-default_sigma=1-lr=0.0001-wd=0.0001-family=bert-hid_dim=128-mlp=0-layer=8-head=8-tokenizer=learnable", "d_m_t")
plot_x_axis, tf_large = load_data(f"good_sweep_1_fixed_256/sigma=1-mu={no_mus}-default_sigma=1-family=bert-hid_dim=16-mlp=0-layer=8-head=4-tokenizer=learnable", "d_m_t")

no_mus = 16
plot_x_axis, tf_small_2 = load_data(f"good_sweep_1_fixed_256/sigma=1-mu={no_mus}-default_sigma=1-family=bert-hid_dim=4-mlp=0-layer=1-head=1-tokenizer=learnable", "d_m_t")
plot_x_axis, tf_med_2 = load_data(f"good_sweep_1_fixed_256/sigma=1-mu={no_mus}-default_sigma=1-family=bert-hid_dim=16-mlp=0-layer=1-head=2-tokenizer=learnable", "d_m_t")
plot_x_axis, tf_large_2 = load_data(f"good_sweep_1_fixed_256/sigma=1-mu={no_mus}-default_sigma=1-family=bert-hid_dim=16-mlp=0-layer=8-head=4-tokenizer=learnable", "d_m_t")

no_mus = 256
plot_x_axis, tf_small_3 = load_data(f"good_sweep_1_fixed_256/sigma=1-mu={no_mus}-default_sigma=1-family=bert-hid_dim=4-mlp=0-layer=1-head=1-tokenizer=learnable", "d_m_t")
plot_x_axis, tf_med_3 = load_data(f"good_sweep_1_fixed_256/sigma=1-mu={no_mus}-default_sigma=1-family=bert-hid_dim=16-mlp=0-layer=1-head=2-tokenizer=learnable", "d_m_t")
plot_x_axis, tf_large_3 = load_data(f"good_sweep_1_fixed_256/sigma=1-mu={no_mus}-default_sigma=1-family=bert-hid_dim=16-mlp=0-layer=8-head=4-tokenizer=learnable", "d_m_t")

plot_x_axis, bayes_c = load_data(f"good_sweep_1_fixed_256/sigma=1-mu={no_mus}-default_sigma=1-family=bert-hid_dim=4-mlp=0-layer=4-head=4-tokenizer=learnable", "d_bc_t")
plot_x_axis, bayes_d = load_data(f"good_sweep_1_fixed_256/sigma=1-mu={no_mus}-default_sigma=1-family=bert-hid_dim=4-mlp=0-layer=4-head=4-tokenizer=learnable", "d_bd_t")

# tf_small = load_data(f"good_sweep_1_fixed_256/sigma=1-mu={no_mus}-default_sigma=1-family=bert-hid_dim=4-mlp=0-layer=1-head=1-tokenizer=learnable", "d_m_t")
# tf_med = load_data(f"good_sweep_1_fixed_256/sigma=1-mu={no_mus}-default_sigma=1-family=bert-hid_dim=16-mlp=0-layer=1-head=2-tokenizer=learnable", "d_m_t")
# tf_large = load_data(f"good_sweep_1_fixed_256/sigma=1-mu={no_mus}-default_sigma=1-lr=0.0001-wd=0.0001-family=bert-hid_dim=256-mlp=0-layer=4-head=4-tokenizer=learnable", "d_m_t")
# bayes_c = load_data(f"good_sweep_1_fixed_256/sigma=1-mu={no_mus}-default_sigma=1-family=bert-hid_dim=4-mlp=0-layer=4-head=4-tokenizer=learnable", "d_bc_t")
# bayes_d = load_data(f"good_sweep_1_fixed_256/sigma=1-mu={no_mus}-default_sigma=1-family=bert-hid_dim=4-mlp=0-layer=4-head=4-tokenizer=learnable", "d_bd_t")


width=450*3
height=350
scale=1

estimator_colors = px.colors.qualitative.Dark24
color_pad = px.colors.qualitative.Dark24
from plotly.subplots import make_subplots

fig = go.Figure()
fig = make_subplots(rows=1, cols=3, 
                    horizontal_spacing=0.05,     
                    subplot_titles=[r"$\Large|\boldsymbol{\mu}_\text{priors}|=2$", 
                                    r"$\Large|\boldsymbol{\mu}_\text{priors}|=16$", 
                                    r"$\Large|\boldsymbol{\mu}_\text{priors}|=256$"])


fig.add_trace(go.Scatter(x=plot_x_axis, y=tf_small, name="TF (Small)",  
                        mode="markers+lines", 
                        marker={'symbol': 'circle', 'color': 'rgba(0, 0, 0, 0)', 'size': 10 * scale, 
                                'line':{'width': 1.5 * scale, 'color': estimator_colors[0]}}, 
                                line={'color': estimator_colors[0], 'width': 1.5 * scale}),    row=1, col=1
 )

fig.add_trace(go.Scatter(x=plot_x_axis, y=tf_med, name="TF (Medium)",  
                        mode="markers+lines", 
                        marker={'symbol': 'circle', 'color': 'rgba(0, 0, 0, 0)', 'size': 10 * scale, 
                                'line':{'width': 1.5 * scale, 'color': estimator_colors[1]}}, 
                                line={'color': estimator_colors[1], 'width': 1.5 * scale}),    row=1, col=1
)

fig.add_trace(go.Scatter(x=plot_x_axis, y=tf_large, name="TF (Large)",  
                        mode="markers+lines", 
                        marker={'symbol': 'circle', 'color': 'rgba(0, 0, 0, 0)', 'size': 10 * scale, 
                                'line':{'width': 1.5 * scale, 'color': estimator_colors[2]}}, 
                                line={'color': estimator_colors[2], 'width': 1.5 * scale}),    row=1, col=1
)

fig.add_trace(go.Scatter(x=plot_x_axis, y=bayes_c, name="Bayes (Cont.)",  
                        mode="lines", 
                        marker={ 'color': 'rgba(0, 0, 0, 0)', 'size': 10 * scale, 
                                'line':{'width': 1.5 * scale, 'color': "black"}}, 
                                line={'color': "black", 'width': 5 * scale, "dash": 'dot'}),    row=1, col=1
)

fig.add_trace(go.Scatter(x=plot_x_axis, y=bayes_d, name="Bayes (Disc.)",  
                        mode="lines", 
                        marker={'color': 'rgba(0, 0, 0, 0)', 'size': 10 * scale, 
                                'line':{'width': 1.5 * scale, 'color': "gray"}}, 
                                line={'color': "gray", 'width': 5 * scale, "dash": 'dot'}),    row=1, col=1
)

fig.add_trace(go.Scatter(x=plot_x_axis, y=tf_small_2, name="TF (Small)",  
                        mode="markers+lines", 
                        marker={'symbol': 'circle', 'color': 'rgba(0, 0, 0, 0)', 'size': 10 * scale, 
                                'line':{'width': 1.5 * scale, 'color': estimator_colors[0]}}, 
                                line={'color': estimator_colors[0], 'width': 1.5 * scale}, showlegend=False),     row=1, col=2
 )

fig.add_trace(go.Scatter(x=plot_x_axis, y=tf_med_2, name="TF (Medium)",  
                        mode="markers+lines", 
                        marker={'symbol': 'circle', 'color': 'rgba(0, 0, 0, 0)', 'size': 10 * scale, 
                                'line':{'width': 1.5 * scale, 'color': estimator_colors[1]}}, 
                                line={'color': estimator_colors[1], 'width': 1.5 * scale}, showlegend=False),     row=1, col=2
)

fig.add_trace(go.Scatter(x=plot_x_axis, y=tf_large_2, name="TF (Large)",  
                        mode="markers+lines", 
                        marker={'symbol': 'circle', 'color': 'rgba(0, 0, 0, 0)', 'size': 10 * scale, 
                                'line':{'width': 1.5 * scale, 'color': estimator_colors[2]}}, 
                                line={'color': estimator_colors[2], 'width': 1.5 * scale}, showlegend=False),     row=1, col=2
)

fig.add_trace(go.Scatter(x=plot_x_axis, y=bayes_c, name="Bayes (Cont.)",  
                        mode="lines", 
                        marker={ 'color': 'rgba(0, 0, 0, 0)', 'size': 10 * scale, 
                                'line':{'width': 1.5 * scale, 'color': "black"}}, 
                                line={'color': "black", 'width': 5 * scale, "dash": 'dot'}, showlegend=False),     row=1, col=2
)

fig.add_trace(go.Scatter(x=plot_x_axis, y=bayes_d, name="Bayes (Disc.)",  
                        mode="lines", 
                        marker={'color': 'rgba(0, 0, 0, 0)', 'size': 10 * scale, 
                                'line':{'width': 1.5 * scale, 'color': "gray"}}, 
                                line={'color': "gray", 'width': 5 * scale, "dash": 'dot'}, showlegend=False),     row=1, col=2
)

fig.add_trace(go.Scatter(x=plot_x_axis, y=tf_small_3, name="TF (Small)",  
                        mode="markers+lines", 
                        marker={'symbol': 'circle', 'color': 'rgba(0, 0, 0, 0)', 'size': 10 * scale, 
                                'line':{'width': 1.5 * scale, 'color': estimator_colors[0]}}, 
                                line={'color': estimator_colors[0], 'width': 1.5 * scale}, showlegend=False),     row=1, col=3
 )

fig.add_trace(go.Scatter(x=plot_x_axis, y=tf_med_3, name="TF (Medium)",  
                        mode="markers+lines", 
                        marker={'symbol': 'circle', 'color': 'rgba(0, 0, 0, 0)', 'size': 10 * scale, 
                                'line':{'width': 1.5 * scale, 'color': estimator_colors[1]}}, 
                                line={'color': estimator_colors[1], 'width': 1.5 * scale}, showlegend=False),     row=1, col=3
)

fig.add_trace(go.Scatter(x=plot_x_axis, y=tf_large_3, name="TF (Large)",  
                        mode="markers+lines", 
                        marker={'symbol': 'circle', 'color': 'rgba(0, 0, 0, 0)', 'size': 10 * scale, 
                                'line':{'width': 1.5 * scale, 'color': estimator_colors[2]}}, 
                                line={'color': estimator_colors[2], 'width': 1.5 * scale}, showlegend=False),     row=1, col=3
)

fig.add_trace(go.Scatter(x=plot_x_axis, y=bayes_c, name="Bayes (Cont.)",  
                        mode="lines", 
                        marker={ 'color': 'rgba(0, 0, 0, 0)', 'size': 10 * scale, 
                                'line':{'width': 1.5 * scale, 'color': "black"}}, 
                                line={'color': "black", 'width': 5 * scale, "dash": 'dot'}, showlegend=False),     row=1, col=3
)

fig.add_trace(go.Scatter(x=plot_x_axis, y=bayes_d, name="Bayes (Disc.)",  
                        mode="lines", 
                        marker={'color': 'rgba(0, 0, 0, 0)', 'size': 10 * scale, 
                                'line':{'width': 1.5 * scale, 'color': "gray"}}, 
                                line={'color': "gray", 'width': 5 * scale, "dash": 'dot'}, 
                                showlegend=False,), 
                                row=1, col=3)


fig.update_layout(
    plot_bgcolor='white',
    showlegend=True
)
fig.update_xaxes(
    range=[0, ticks],
    mirror=True,
    ticks='outside',
    title="Training Steps",
    showline=True,
    linecolor='black',
    gridcolor='lightgrey'
)
fig.update_yaxes(
    range=[-0.05, 0.6],
    mirror=True,
    ticks='outside',
    showline=True,
    linecolor='black',
    gridcolor='lightgrey'
)

fig.update_layout(width=width*scale, 
                height=height*scale, 
                font=dict(size=20 * scale),
                # yaxis_range=[-0.05, 1],
                # xaxis_range=[0, 20],
                xaxis_title="Training Steps",
                yaxis_title="Normalized Risk",
                margin=dict(l=0, r=0, t=40, b=0),
                legend=dict(
                    # x=0.65, y=0.97, 
                            bordercolor="Black", borderwidth=1))

fig.show()
fig.write_image("a_1_mu=2,16,256.pdf")
fig.write_image("a_1_mu=2,16,256.pdf")

# %%
no_mus = 16
prior = "c"
plot=True

ticks = 25
plot_x_data = [str(i) for i in np.arange(0, 100050, 50)]

def load_data(model_dir, model_key):
    mu_data = json.load(open(os.path.join(model_dir, "plot_data.json"), "r"))

    data = []
    final_epoch = 0
    for epoch in mu_data:
        if int(epoch) % 50 == 0:
            final_epoch = epoch
            data.append(mu_data[epoch][model_key])

    if epoch != plot_x_data[-1]:
        for _ in plot_x_data[plot_x_data.index(final_epoch)+1:]:
            data.append(data[-1])
    
    tick_size = int(len(plot_x_data) / ticks)

    plot_x_axis = []
    plot_y_axis = []
    
    index = 0

    while index <= len(plot_x_data):
        plot_x_axis.append(plot_x_data[index])
        plot_y_axis.append(data[index])
        index += tick_size

    return plot_x_axis, plot_y_axis

plot_x_axis, tf_small = load_data(f"good_sweep_1_fixed_256/sigma=1-mu={no_mus}-default_sigma=1-family=bert-hid_dim=4-mlp=0-layer=1-head=1-tokenizer=learnable", f"{prior}_m_t")
plot_x_axis, tf_med = load_data(f"good_sweep_1_fixed_256/sigma=1-mu={no_mus}-default_sigma=1-family=bert-hid_dim=16-mlp=0-layer=1-head=2-tokenizer=learnable", f"{prior}_m_t")
plot_x_axis, tf_large = load_data(f"good_sweep_1_fixed_256/sigma=1-mu={no_mus}-default_sigma=1-family=bert-hid_dim=16-mlp=0-layer=8-head=4-tokenizer=learnable", f"{prior}_m_t")
plot_x_axis, bayes_c = load_data(f"good_sweep_1_fixed_256/sigma=1-mu={no_mus}-default_sigma=1-family=bert-hid_dim=4-mlp=0-layer=4-head=4-tokenizer=learnable", f"{prior}_bc_t")
plot_x_axis, bayes_d = load_data(f"good_sweep_1_fixed_256/sigma=1-mu={no_mus}-default_sigma=1-family=bert-hid_dim=4-mlp=0-layer=4-head=4-tokenizer=learnable", f"{prior}_bd_t")

showlegend = False
yaxis_range = [-0.05, 1.5]

if plot:
    width=450
    height=350
    scale=1

    estimator_colors = px.colors.qualitative.Dark24
    color_pad = px.colors.qualitative.Dark24
    from plotly.subplots import make_subplots
    import re

    plot_x_axis = [re.sub("000$", "K", i) for i in plot_x_axis]

    fig = go.Figure()

    fig.add_trace(go.Scatter(x=plot_x_axis, y=tf_small, name="TF (Small)",  
                            mode="markers+lines", 
                            marker={'symbol': 'circle', 'color': 'rgba(0, 0, 0, 0)', 'size': 10 * scale, 
                                    'line':{'width': 1.5 * scale, 'color': estimator_colors[4]}}, 
                                    line={'color': estimator_colors[4], 'width': 1.5 * scale})
    )

    fig.add_trace(go.Scatter(x=plot_x_axis, y=tf_med, name="TF (Medium)",  
                            mode="markers+lines", 
                            marker={'symbol': 'circle', 'color': 'rgba(0, 0, 0, 0)', 'size': 10 * scale, 
                                    'line':{'width': 1.5 * scale, 'color': "blue"}}, 
                                    line={'color': "blue", 'width': 1.5 * scale})
    )

    fig.add_trace(go.Scatter(x=plot_x_axis, y=tf_large, name="TF (Large)",  
                            mode="markers+lines", 
                            marker={'symbol': 'circle', 'color': 'rgba(0, 0, 0, 0)', 'size': 10 * scale, 
                                    'line':{'width': 1.5 * scale, 'color': "green"}}, 
                                    line={'color': "green", 'width': 1.5 * scale})
    )

    fig.add_trace(go.Scatter(x=plot_x_axis, y=bayes_c, name="Bayes (Cont.)",  
                            mode="lines", 
                            marker={ 'color': 'rgba(0, 0, 0, 0)', 'size': 10 * scale, 
                                    'line':{'width': 1.5 * scale, 'color': "black"}}, 
                                    line={'color': "black", 'width': 5 * scale, "dash": 'dot'})
    )

    fig.add_trace(go.Scatter(x=plot_x_axis, y=bayes_d, name="Bayes (Disc.)",  
                            mode="lines", 
                            marker={'color': 'rgba(0, 0, 0, 0)', 'size': 10 * scale, 
                                    'line':{'width': 1.5 * scale, 'color': "red"}}, 
                                    line={'color': "red", 'width': 5 * scale, "dash": 'dot'})
    )


    fig.update_layout(
        plot_bgcolor='white',
        showlegend=showlegend
    )
    fig.update_xaxes(
        range=[0, ticks],
        mirror=True,
        ticks='outside',
        title="Training Steps",
        showline=True,
        linecolor='black',
        gridcolor='lightgrey',
        tickangle=45,
        tickfont = dict(size=15)
    )
    fig.update_yaxes(
        # range=[-0.05, 0.6],
        mirror=True,
        ticks='outside',
        title="Normalized Risk",
        showline=True,
        linecolor='black',
        gridcolor='lightgrey',
        tickfont = dict(size=15)
    )

    fig.update_layout(width=width*scale, 
                    height=height*scale, 
                    font=dict(size=20 * scale),
                    yaxis_range=yaxis_range,
                    # xaxis_range=[0, 20],
                    # xaxis_title="Training Steps",
                    # yaxis_title="Normalized Risk",
                    margin=dict(l=0, r=0, t=0, b=0),
                    legend=dict(
                        font = dict(size = 15),
                        x=0.6, y=0.4, 
                                bordercolor="Black", borderwidth=1))

    fig.show()

fig.write_image(f"a_1_mu={no_mus}_c.pdf")
fig.write_image(f"a_1_mu={no_mus}_c.pdf")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[27], line 39
#      37 plot_x_axis, tf_med = load_data(f"good_sweep_1_fixed_256/sigma=1-mu={no_mus}-default_sigma=1-family=bert-hid_dim=16-mlp=0-layer=1-head=2-tokenizer=learnable", f"{prior}_m_t")
#      38 plot_x_axis, tf_large = load_data(f"good_sweep_1_fixed_256/sigma=1-mu={no_mus}-default_sigma=1-family=bert-hid_dim=16-mlp=0-layer=8-head=4-tokenizer=learnable", f"{prior}_m_t")
# ---> 39 plot_x_axis, bayes_c = load_data(f"good_sweep_1_fixed_256/sigma=1-mu={no_mus}-default_sigma=1-family=bert-hid_dim=4-mlp=0-layer=4-head=4-tokenizer=learnable", f"{prior}_bc_t")
#      40 plot_x_axis, bayes_d = load_data(f"good_sweep_1_fixed_256/sigma=1-mu={no_mus}-default_sigma=1-family=bert-hid_dim=4-mlp=0-layer=4-head=4-tokenizer=learnable", f"{prior}_bd_t")
#      42 showlegend = False
#
# ...

# %%
ticks = 25
no_mus = 256
plot_x_data = [str(i) for i in np.arange(0, 100050, 50)]

def load_data(model_dir, model_key):
    mu_data = json.load(open(os.path.join(model_dir, "plot_data.json"), "r"))

    data = []
    final_epoch = 0
    for epoch in mu_data:
        if int(epoch) % 50 == 0:
            final_epoch = epoch
            data.append(mu_data[epoch][model_key])

    if epoch != plot_x_data[-1]:
        for _ in plot_x_data[plot_x_data.index(final_epoch)+1:]:
            data.append(data[-1])
    
    tick_size = int(len(plot_x_data) / ticks)

    plot_x_axis = []
    plot_y_axis = []
    
    index = 0

    while index <= len(plot_x_data):
        plot_x_axis.append(plot_x_data[index])
        plot_y_axis.append(data[index])
        index += tick_size

    return plot_x_axis, plot_y_axis

no_mus = 32
plot_x_axis, tf_1 = load_data(f"good_sweep_1_fixed_256/sigma=1-mu={no_mus}-default_sigma=1-family=bert-hid_dim=64-mlp=0-layer=1-head=1-tokenizer=learnable", "d_m_t")
plot_x_axis, tf_2 = load_data(f"good_sweep_1_fixed_256/sigma=1-mu={no_mus}-default_sigma=1-family=bert-hid_dim=64-mlp=0-layer=2-head=1-tokenizer=learnable", "d_m_t")
plot_x_axis, tf_3 = load_data(f"good_sweep_1_fixed_256/sigma=1-mu={no_mus}-default_sigma=1-family=bert-hid_dim=64-mlp=0-layer=4-head=1-tokenizer=learnable", "d_m_t")
plot_x_axis, tf_4 = load_data(f"good_sweep_1_fixed_256/sigma=1-mu={no_mus}-default_sigma=1-family=bert-hid_dim=64-mlp=0-layer=8-head=1-tokenizer=learnable", "d_m_t")

plot_x_axis, bayes_c = load_data(f"good_sweep_1_fixed_256/sigma=1-mu={no_mus}-default_sigma=1-family=bert-hid_dim=4-mlp=0-layer=4-head=4-tokenizer=learnable", "d_bc_t")
plot_x_axis, bayes_d = load_data(f"good_sweep_1_fixed_256/sigma=1-mu={no_mus}-default_sigma=1-family=bert-hid_dim=4-mlp=0-layer=4-head=4-tokenizer=learnable", "d_bd_t")


width=450
height=350
scale=1

estimator_colors = px.colors.qualitative.Dark24
color_pad = px.colors.qualitative.Dark24
from plotly.subplots import make_subplots
import re

plot_x_axis = [re.sub("000$", "K", i) for i in plot_x_axis]

fig = go.Figure()

fig.add_trace(go.Scatter(x=plot_x_axis, y=tf_1, name="TF (1 Layer)",  
                        mode="markers+lines", 
                        marker={'symbol': 'circle', 'color': 'rgba(0, 0, 0, 0)', 'size': 10 * scale, 
                                'line':{'width': 1.5 * scale, 'color': estimator_colors[4]}}, 
                                line={'color': estimator_colors[4], 'width': 1.5 * scale})
 )

fig.add_trace(go.Scatter(x=plot_x_axis, y=tf_2, name="TF (2 Layers)",  
                        mode="markers+lines", 
                        marker={'symbol': 'circle', 'color': 'rgba(0, 0, 0, 0)', 'size': 10 * scale, 
                                'line':{'width': 1.5 * scale, 'color': "blue"}}, 
                                line={'color': "blue", 'width': 1.5 * scale})
)

fig.add_trace(go.Scatter(x=plot_x_axis, y=tf_3, name="TF (4 Layers)",  
                        mode="markers+lines", 
                        marker={'symbol': 'circle', 'color': 'rgba(0, 0, 0, 0)', 'size': 10 * scale, 
                                'line':{'width': 1.5 * scale, 'color': "green"}}, 
                                line={'color': "green", 'width': 1.5 * scale})
)

fig.add_trace(go.Scatter(x=plot_x_axis, y=tf_4, name="TF (8 Layers)",  
                        mode="markers+lines", 
                        marker={'symbol': 'circle', 'color': 'rgba(0, 0, 0, 0)', 'size': 10 * scale, 
                                'line':{'width': 1.5 * scale, 'color': estimator_colors[5]}}, 
                                line={'color': estimator_colors[5], 'width': 1.5 * scale})
)

fig.add_trace(go.Scatter(x=plot_x_axis, y=bayes_c, name="Bayes (Cont.)",  
                        mode="lines", 
                        marker={ 'color': 'rgba(0, 0, 0, 0)', 'size': 10 * scale, 
                                'line':{'width': 1.5 * scale, 'color': "black"}}, 
                                line={'color': "black", 'width': 5 * scale, "dash": 'dot'})
)

fig.add_trace(go.Scatter(x=plot_x_axis, y=bayes_d, name="Bayes (Disc.)",  
                        mode="lines", 
                        marker={'color': 'rgba(0, 0, 0, 0)', 'size': 10 * scale, 
                                'line':{'width': 1.5 * scale, 'color': "red"}}, 
                                line={'color': "red", 'width': 5 * scale, "dash": 'dot'})
)


fig.update_layout(
    plot_bgcolor='white',
    showlegend=True
)
fig.update_xaxes(
    range=[0, ticks],
    mirror=True,
    ticks='outside',
    title="Training Steps",
    showline=True,
    linecolor='black',
    gridcolor='lightgrey',
    tickangle=45,
    tickfont = dict(size=15)
)
fig.update_yaxes(
    range=[-0.05, 0.6],
    mirror=True,
    ticks='outside',
    title="Normalized Risk",
    showline=True,
    linecolor='black',
    gridcolor='lightgrey',
    tickfont = dict(size=15)
)

fig.update_layout(width=width, 
                height=height*scale, 
                font=dict(size=20 * scale),
                margin=dict(l=0, r=0, t=0, b=0),
                legend=dict(
                    font = dict(size = 10),
                    x=0.7, y=0.33, 
                            bordercolor="Black", borderwidth=1))

fig.show()
fig.write_image(f"a_2_layers.pdf")
fig.write_image(f"a_2_layers.pdf")

# %%
ticks = 25
no_mus = 16
plot_x_data = [str(i) for i in np.arange(0, 100050, 50)]

def load_data(model_dir, model_key):
    mu_data = json.load(open(os.path.join(model_dir, "plot_data.json"), "r"))

    data = []
    final_epoch = 0
    for epoch in mu_data:
        if int(epoch) % 50 == 0:
            final_epoch = epoch
            data.append(mu_data[epoch][model_key])

    if epoch != plot_x_data[-1]:
        for _ in plot_x_data[plot_x_data.index(final_epoch)+1:]:
            data.append(data[-1])
    
    tick_size = int(len(plot_x_data) / ticks)

    plot_x_axis = []
    plot_y_axis = []
    
    index = 0

    while index <= len(plot_x_data):
        plot_x_axis.append(plot_x_data[index])
        plot_y_axis.append(data[index])
        index += tick_size

    return plot_x_axis, plot_y_axis

no_mus = 256
plot_x_axis, tf_1 = load_data(f"good_sweep_1_fixed_256/sigma=1-mu={no_mus}-default_sigma=1-family=bert-hid_dim=4-mlp=0-layer=1-head=1-tokenizer=learnable", "c_m_t")
plot_x_axis, tf_2 = load_data(f"good_sweep_1_fixed_256/sigma=1-mu={no_mus}-default_sigma=1-family=bert-hid_dim=16-mlp=0-layer=1-head=1-tokenizer=learnable", "c_m_t")
plot_x_axis, tf_3 = load_data(f"good_sweep_1_fixed_256/sigma=1-mu={no_mus}-default_sigma=1-family=bert-hid_dim=64-mlp=0-layer=4-head=4-tokenizer=learnable", "c_m_t")
plot_x_axis, tf_4 = load_data(f"good_sweep_1_fixed_256/sigma=1-mu={no_mus}-default_sigma=1-family=bert-hid_dim=256-mlp=0-layer=1-head=1-tokenizer=learnable", "c_m_t")

plot_x_axis, bayes_c = load_data(f"good_sweep_1_fixed_256/sigma=1-mu={no_mus}-default_sigma=1-family=bert-hid_dim=4-mlp=0-layer=4-head=4-tokenizer=learnable", "c_bc_t")
plot_x_axis, bayes_d = load_data(f"good_sweep_1_fixed_256/sigma=1-mu={no_mus}-default_sigma=1-family=bert-hid_dim=4-mlp=0-layer=4-head=4-tokenizer=learnable", "c_bd_t")


width=450
height=350
scale=1

estimator_colors = px.colors.qualitative.Dark24
color_pad = px.colors.qualitative.Dark24
from plotly.subplots import make_subplots
import re

plot_x_axis = [re.sub("000$", "K", i) for i in plot_x_axis]

fig = go.Figure()

fig.add_trace(go.Scatter(x=plot_x_axis, y=tf_1, name="TF (1 Head)",  
                        mode="markers+lines", 
                        marker={'symbol': 'circle', 'color': 'rgba(0, 0, 0, 0)', 'size': 10 * scale, 
                                'line':{'width': 1.5 * scale, 'color': estimator_colors[4]}}, 
                                line={'color': estimator_colors[4], 'width': 1.5 * scale})
 )

fig.add_trace(go.Scatter(x=plot_x_axis, y=tf_2, name="TF (2 Heads)",  
                        mode="markers+lines", 
                        marker={'symbol': 'circle', 'color': 'rgba(0, 0, 0, 0)', 'size': 10 * scale, 
                                'line':{'width': 1.5 * scale, 'color': "blue"}}, 
                                line={'color': "blue", 'width': 1.5 * scale})
)

fig.add_trace(go.Scatter(x=plot_x_axis, y=tf_3, name="TF (4 Heads)",  
                        mode="markers+lines", 
                        marker={'symbol': 'circle', 'color': 'rgba(0, 0, 0, 0)', 'size': 10 * scale, 
                                'line':{'width': 1.5 * scale, 'color': "green"}}, 
                                line={'color': "green", 'width': 1.5 * scale})
)

fig.add_trace(go.Scatter(x=plot_x_axis, y=tf_4, name="TF (8 Heads)",  
                        mode="markers+lines", 
                        marker={'symbol': 'circle', 'color': 'rgba(0, 0, 0, 0)', 'size': 10 * scale, 
                                'line':{'width': 1.5 * scale, 'color': estimator_colors[5]}}, 
                                line={'color': estimator_colors[5], 'width': 1.5 * scale})
)

fig.add_trace(go.Scatter(x=plot_x_axis, y=bayes_c, name="Bayes (Cont.)",  
                        mode="lines", 
                        marker={ 'color': 'rgba(0, 0, 0, 0)', 'size': 10 * scale, 
                                'line':{'width': 1.5 * scale, 'color': "black"}}, 
                                line={'color': "black", 'width': 5 * scale, "dash": 'dot'})
)

fig.add_trace(go.Scatter(x=plot_x_axis, y=bayes_d, name="Bayes (Disc.)",  
                        mode="lines", 
                        marker={'color': 'rgba(0, 0, 0, 0)', 'size': 10 * scale, 
                                'line':{'width': 1.5 * scale, 'color': "red"}}, 
                                line={'color': "red", 'width': 5 * scale, "dash": 'dot'})
)


fig.update_layout(
    plot_bgcolor='white',
    showlegend=True
)
fig.update_xaxes(
    range=[0, ticks],
    mirror=True,
    ticks='outside',
    title="Training Steps",
    showline=True,
    linecolor='black',
    gridcolor='lightgrey',
    tickangle=45,
    tickfont = dict(size=15)
)
fig.update_yaxes(
    # range=[-0.05, 0.6],
    mirror=True,
    ticks='outside',
    title="Normalized Risk",
    showline=True,
    linecolor='black',
    gridcolor='lightgrey',
    tickfont = dict(size=15)
)

fig.update_layout(width=width, 
                height=height*scale, 
                font=dict(size=20 * scale),
                margin=dict(l=0, r=0, t=0, b=0),
                legend=dict(
                    font = dict(size = 10),
                    x=0.7, y=0.33, 
                            bordercolor="Black", borderwidth=1))

fig.show()
# fig.write_image(f"a_2_dim.pdf")
# fig.write_image(f"a_2_dim.pdf")

# %%
x = json.load(open(os.path.join("good_sweep_1_fixed_256/sigma=1-mu=16-default_sigma=1-family=bert-hid_dim=4-mlp=0-layer=1-head=1-tokenizer=learnable", "plot_data.json"), "r"))

# %%
import itertools

# %%
prior = "d"
no_mus = 64
showlegend = True

plot=True

hid_dims = [4, 16, 64, 256]
depth_params = [1,2,4,8]
width_params = [1,2,4]

def load_data(model_dir, model_key):
    mu_data = json.load(open(os.path.join(model_dir, "plot_data.json"), "r"))

    return mu_data[list(mu_data.keys())[-1]][model_key]

params_to_graph_hid_dim = {}
for param in [element for element in itertools.product(*[depth_params, width_params])]:
    d, w = param
    plot_data = []
    for hid_dim in hid_dims:
        try:
            plot_data.append(load_data(f"good_sweep_1_fixed_256/sigma=1-mu={no_mus}-default_sigma=1-family=bert-hid_dim={hid_dim}-mlp=0-layer={d}-head={w}-tokenizer=learnable", 
                             f"{prior}_m_t"))
        except FileNotFoundError:
            continue
    
    if len(plot_data) == len(hid_dims):
        params_to_graph_hid_dim[param] = plot_data

params_to_graph_depth = {}
for param in [element for element in itertools.product(*[hid_dims, width_params])]:
    hid_dim, w = param
    plot_data = []
    for d in depth_params:
        try:
            plot_data.append(load_data(f"good_sweep_1_fixed_256/sigma=1-mu={no_mus}-default_sigma=1-family=bert-hid_dim={hid_dim}-mlp=0-layer={d}-head={w}-tokenizer=learnable", 
                             f"{prior}_m_t"))
        except FileNotFoundError:
            continue
    
    if len(plot_data) == len(depth_params):
        params_to_graph_depth[param] = plot_data

params_to_graph_width = {}
for param in [element for element in itertools.product(*[hid_dims, depth_params])]:
    hid_dim, d = param
    plot_data = []
    for w in width_params:
        try:
            plot_data.append(load_data(f"good_sweep_1_fixed_256/sigma=1-mu={no_mus}-default_sigma=1-family=bert-hid_dim={hid_dim}-mlp=0-layer={d}-head={w}-tokenizer=learnable", 
                             f"{prior}_m_t"))
        except FileNotFoundError:
            continue
    
    if len(plot_data) == len(width_params):
        params_to_graph_width[param] = plot_data

# %%
bd = load_data(f"good_sweep_1_fixed_256/sigma=1-mu={no_mus}-default_sigma=1-family=bert-hid_dim={hid_dim}-mlp=0-layer={d}-head={w}-tokenizer=learnable", 
                             f"{prior}_bd_t")
bc = load_data(f"good_sweep_1_fixed_256/sigma=1-mu={no_mus}-default_sigma=1-family=bert-hid_dim={hid_dim}-mlp=0-layer={d}-head={w}-tokenizer=learnable", 
                             f"{prior}_bc_t")

# %%
width=450
height=350
scale=1

colors = [
"rgb(0, 149, 255)",
"rgb(73, 143, 255)",
"rgb(108, 135, 254)",
"rgb(137, 126, 249)",
"rgb(162, 116, 242)",
"rgb(184, 105, 232)",
"rgb(204, 92, 219)",
"rgb(221, 78, 204)",
"rgb(235, 60, 187)",
"rgb(247, 39, 168)",
"rgb(255, 1, 148)",
"rgb(255, 0, 127)",
"rgb(255, 0, 104)",
"rgb(255, 0, 82)",
"rgb(255, 0, 58)",
"rgb(255, 0, 31)",
]
def generate_plots(plot_x_axis, params_to_graph, label, x_axis):
    fig = go.Figure()
    for index, param in enumerate(params_to_graph):
        d, w = param
        fig.add_trace(go.Scatter(x=plot_x_axis, 
                                    y=params_to_graph[param], 
                                    name=f"{d}{label[0]}, {w}{label[1]}",
                                    mode="markers+lines", 
                                    marker={'symbol': 'circle', 
                                            'color': 'rgba(0, 0, 0, 0)', 
                                            'size': 10 * scale, 
                                            'line':{'width': 1.5 * scale, 
                                                    'color': colors[index]}}, 
                                                    line={'color': colors[index], 
                                                        'width': 1.5 * scale}))
    
    fig.add_trace(go.Scatter(x=plot_x_axis, 
                            y=[bd] * len(params_to_graph[param]), 
                            name=f"Bayes (Disc.)",
                            mode="lines", 
                            marker={'color': 'rgba(0, 0, 0, 0)', 'size': 10 * scale, 
                                    'line':{'width': 1.5 * scale, 'color': "black"}}, 
                                    line={'color': "black", 'width': 5 * scale, "dash": 'dot'}))

    fig.add_trace(go.Scatter(x=plot_x_axis, 
                            y=[bc] * len(params_to_graph[param]), 
                            name=f"Bayes (Cont.)",
                            mode="lines", 
                            marker={'color': 'rgba(0, 0, 0, 0)', 'size': 10 * scale, 
                                    'line':{'width': 1.5 * scale, 'color': "red"}}, 
                                    line={'color': "red", 'width': 5 * scale, "dash": 'dot'}))

    fig.update_layout(
        plot_bgcolor='white',
        showlegend=True
    )
    fig.update_xaxes(
        mirror=True,
        ticks='outside',
        title=x_axis,
        showline=True,
        linecolor='black',
        gridcolor='lightgrey',
        tickangle=45,
        tickfont = dict(size=15)
    )
    fig.update_yaxes(
        mirror=True,
        ticks='outside',
        title="Normalized Risk",
        showline=True,
        linecolor='black',
        gridcolor='lightgrey',
        tickfont = dict(size=15)
    )

    fig.update_layout(width=width*scale*1.2, 
                    height=height*scale, 
                    font=dict(size=20 * scale),
                    margin=dict(l=0, r=0, t=0, b=0),
                    legend=dict(
                        font = dict(size = 8),
                        # x=0.6, y=0.4, 
                                bordercolor="Black", borderwidth=1))

    return fig

# generate_plots(hid_dims, params_to_graph_hid_dim, ["D", "W"], "Hidden Dimension").write_image("a_3_hid_dim.pdf")
# generate_plots(depth_params, params_to_graph_depth, ["H", "W"], "Depth").write_image("a_3_depth.pdf")
# generate_plots(width_params, params_to_graph_width, ["H", "D"], "Width").write_image("a_3_width.pdf")
generate_plots(hid_dims, params_to_graph_hid_dim, ["D", "W"], "Hidden Dimension").show()
generate_plots(depth_params, params_to_graph_depth, ["H", "W"], "Depth").show()
generate_plots(width_params, params_to_graph_width, ["H", "D"], "Width").show()
